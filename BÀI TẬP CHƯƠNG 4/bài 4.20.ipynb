# %%
import pandas as pd

# %%
euro2012=pd.read_csv("euro2012.csv")
euro2012
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %% [markdown]
# phần 1:

# %%
print("Cột Goals là :")
euro2012["Goals"]
# Out:
# Cột Goals là :
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# phần 2:

# %%
num_teams=euro2012.shape[0]
print("Số đội tham gia là:",num_teams)
# Out:
# Số đội tham gia là: 16

# %% [markdown]
# phần 3

# %%
print("Thông tin của euro 2012 là:")
euro2012.info()
# Out:
# Thông tin của euro 2012 là:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  16 non-null     int64
#  1   Team                        16 non-null     object
#  2   Goals                       16 non-null     int64
#  3   Shots on target             16 non-null     int64
#  4   Shots off target            16 non-null     int64
#  5   Shooting Accuracy           16 non-null     object
#  6   % Goals-to-shots            16 non-null     object
#  7   Total shots (inc. Blocked)  16 non-null     int64
#  8   Hit Woodwork                16 non-null     int64
#  9   Penalty goals               16 non-null     int64
#  10  Penalties not scored        16 non-null     int64
#  11  Headed goals                16 non-null     int64
#  12  Passes                      16 non-null     int64
# ...

# %% [markdown]
# phần 4:

# %%
discipline=euro2012[['Team','Yellow Cards','Red Cards']]
print("DataFrame mới:")
discipline
# Out:
# DataFrame mới:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# phần 5:

# %%
discipline_sorted=discipline.sort_values(by=['Red Cards','Yellow Cards'],ascending=False)
print("Sau sắp xếp là:")
discipline_sorted
# Out:
# Sau sắp xếp là:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %% [markdown]
# phần 6.a:

# %%
yellow_cards_mean=euro2012['Yellow Cards'].mean()
print("Trung bình Yellow Cards là: ",yellow_cards_mean)
# Out:
# Trung bình Yellow Cards là:  7.4375

# %% [markdown]
# phần 6.b:

# %%
teams_more_than_5_goals=euro2012[euro2012['Goals']>5]
print("Những đội có bàn thắng lớn hơn 5 là:")
teams_more_than_5_goals
# Out:
# Những đội có bàn thắng lớn hơn 5 là:
#     Unnamed: 0      Team  Goals  Shots on target  Shots off target  \
# 5            5   Germany     10               32                32
# 7            7     Italy      6               34                45
# 10          10  Portugal      6               22                42
# 13          13     Spain     12               42                33
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 5             47.80%           15.60%                          80
# 7             43.00%            7.50%                         110
# 10            34.30%            9.30%                          82
# 13            55.90%           16.00%                         100
#
#     Hit Woodwork  Penalty goals  ...  Saves made  Saves-to-shots ratio  \
# 5              2              1  ...          10                62.60%
# 7              2              0  ...          20                74.10%
# ...

# %% [markdown]
# phần 7:

# %%
team_starting_with_G=euro2012[euro2012['Team'].str.startswith('G')]
print("những team có chữ cái đầu tiên là G là:")
team_starting_with_G
# Out:
# những team có chữ cái đầu tiên là G là:
#    Unnamed: 0     Team  Goals  Shots on target  Shots off target  \
# 5           5  Germany     10               32                32
# 6           6   Greece      5                8                18
#
#   Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 5            47.80%           15.60%                          80
# 6            30.70%           19.20%                          32
#
#    Hit Woodwork  Penalty goals  ...  Saves made  Saves-to-shots ratio  \
# 5             2              1  ...          10                62.60%
# 6             1              1  ...          13                65.10%
#
#    Fouls Won  Fouls Conceded Offsides  Yellow Cards  Red Cards  Subs on  \
# 5         63              49       12             4          0       15
# 6         67              48       12             9          1       12
#
#    Subs off  Players Used
# 5        15            17
# 6        12            20
#
# ...

# %% [markdown]
# phần 8:

# %%
all_except_last_3=euro2012.iloc[:,:-3]
print("Dữ liệu trừ 3 cột cuối là:")
all_except_last_3
# Out:
# Dữ liệu trừ 3 cột cuối là:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %% [markdown]
# phần 9:

# %%
columns_to_show=['Team','Goals','Shooting Accuracy','Yellow Cards','Red Cards']
print("Các cột cần hiển thị là:")
euro2012[columns_to_show]
# Out:
# Các cột cần hiển thị là:
#                    Team  Goals Shooting Accuracy  Yellow Cards  Red Cards
# 0               Croatia      4            51.90%             9          0
# 1        Czech Republic      4            41.90%             7          0
# 2               Denmark      4            50.00%             4          0
# 3               England      5            50.00%             5          0
# 4                France      3            37.90%             6          0
# 5               Germany     10            47.80%             4          0
# 6                Greece      5            30.70%             9          1
# 7                 Italy      6            43.00%            16          0
# 8           Netherlands      2            25.00%             5          0
# 9                Poland      2            39.40%             7          1
# 10             Portugal      6            34.30%            12          0
# ...

# %% [markdown]
# phần 10:

# %%
specific_team=euro2012[euro2012['Team'].isin(['Enagland','Italy','Russia'])]
print("Các đội England,Italy,Russia:")
specific_team
# Out:
# Các đội England,Italy,Russia:
#     Unnamed: 0    Team  Goals  Shots on target  Shots off target  \
# 7            7   Italy      6               34                45
# 12          12  Russia      5                9                31
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 7             43.00%            7.50%                         110
# 12            22.50%           12.50%                          59
#
#     Hit Woodwork  Penalty goals  ...  Saves made  Saves-to-shots ratio  \
# 7              2              0  ...          20                74.10%
# 12             2              0  ...          10                77.00%
#
#     Fouls Won  Fouls Conceded Offsides  Yellow Cards  Red Cards  Subs on  \
# 7         101              89       16            16          0       18
# 12         34              43        4             6          0        7
#
#     Subs off  Players Used
# 7         18            19
# 12         7            16
#
# ...
